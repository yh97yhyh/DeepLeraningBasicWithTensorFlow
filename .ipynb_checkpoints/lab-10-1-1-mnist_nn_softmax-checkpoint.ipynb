# %% [markdown]
# ## import

# %%
import os
import tensorflow as tf
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
from time import time

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.random.set_seed(777)  # for reproducibility
print(tf.__version__)
# Out:
# 2.8.0

# %% [markdown]
# ## Checkpoint function

# %%
def load(model, checkpoint_dir):
    print(" [*] Reading checkpoints...")

    ckpt = tf.train.get_checkpoint_state(checkpoint_dir)
    if ckpt :
        ckpt_name = os.path.basename(ckpt.model_checkpoint_path)
        checkpoint = tf.train.Checkpoint(dnn=model)
        checkpoint.restore(save_path=os.path.join(checkpoint_dir, ckpt_name))
        counter = int(ckpt_name.split('-')[1])
        print(" [*] Success to read {}".format(ckpt_name))
        return True, counter
    else:
        print(" [*] Failed to find a checkpoint")
        return False, 0

def check_folder(dir):
    if not os.path.exists(dir):
        os.makedirs(dir)
    return dir

# %% [markdown]
# ## Data load & pre-proceessing function

# %%
def load_mnist() :
    (train_data, train_labels), (test_data, test_labels) = mnist.load_data()
    train_data = np.expand_dims(train_data, axis=-1) # [N, 28, 28] -> [N, 28, 28, 1]
    test_data = np.expand_dims(test_data, axis=-1) # [N, 28, 28] -> [N, 28, 28, 1]

    train_data, test_data = normalize(train_data, test_data)

    train_labels = to_categorical(train_labels, 10) # [N,] -> [N, 10]
    test_labels = to_categorical(test_labels, 10) # [N,] -> [N, 10]

    return train_data, train_labels, test_data, test_labels

def normalize(train_data, test_data):
    train_data = train_data.astype(np.float32) / 255.0
    test_data = test_data.astype(np.float32) / 255.0

    return train_data, test_data

# %% [markdown]
# ## Performance function

# %%
def loss_fn(model, images, labels):
    logits = model(images, training=True)    
    loss = tf.reduce_mean(tf.keras.losses.categorical_crossentropy(y_pred=logits, y_true=labels, 
                                                                   from_logits=True))
    return loss

def accuracy_fn(model, images, labels):
    logits = model(images, training=False)
    prediction = tf.equal(tf.argmax(logits, -1), tf.argmax(labels, -1))
    accuracy = tf.reduce_mean(tf.cast(prediction, tf.float32))
    return accuracy

def grad(model, images, labels):
    with tf.GradientTape() as tape:
        loss = loss_fn(model, images, labels)
    return tape.gradient(loss, model.variables)

# %% [markdown]
# ## Model function

# %%
def flatten() :
    return tf.keras.layers.Flatten()

def dense(label_dim, weight_init) :
    return tf.keras.layers.Dense(units=label_dim, use_bias=True, kernel_initializer=weight_init)

def sigmoid() :
    return tf.keras.layers.Activation(tf.keras.activations.sigmoid)

# %% [markdown]
# ## Create model (class version)

# %%
class create_model_class(tf.keras.Model):
    def __init__(self, label_dim):
        super(create_model_class, self).__init__()
        weight_init = tf.keras.initializers.RandomNormal()

        self.model = tf.keras.Sequential()
        self.model.add(flatten())

        for i in range(2):
            self.model.add(dense(256, weight_init))
            self.model.add(sigmoid())

        self.model.add(dense(label_dim, weight_init))

    def call(self, x, training=None, mask=None):
        x = self.model(x)

        return x

# %% [markdown]
# ## Create model (function version)

# %%
def create_model_function(label_dim) :
    weight_init = tf.keras.initializers.RandomNormal()

    model = tf.keras.Sequential()
    model.add(flatten())

    for i in range(2) :
        model.add(dense(256, weight_init))
        model.add(sigmoid())

    model.add(dense(label_dim, weight_init))

    return model

# %% [markdown]
# ## Define data & hyper-parameter

# %%
""" dataset """
train_x, train_y, test_x, test_y = load_mnist()

""" parameters """
learning_rate = 0.001
batch_size = 128

training_epochs = 1
training_iterations = len(train_x) // batch_size

label_dim = 10

train_flag = True

""" Graph Input using Dataset API """
train_dataset = tf.data.Dataset.from_tensor_slices((train_x, train_y)).\
    shuffle(buffer_size=100000).\
    prefetch(buffer_size=batch_size).\
    batch(batch_size, drop_remainder=True)

test_dataset = tf.data.Dataset.from_tensor_slices((test_x, test_y)).\
    shuffle(buffer_size=100000).\
    prefetch(buffer_size=len(test_x)).\
    batch(len(test_x))

# %% [markdown]
# ## Define model & optimizer & writer

# %%
""" Model """
network = create_model_function(label_dim)

""" Training """
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

""" Writer """
checkpoint_dir = 'checkpoints'
logs_dir = 'logs'

model_dir = 'nn_softmax'

checkpoint_dir = os.path.join(checkpoint_dir, model_dir)
check_folder(checkpoint_dir)
checkpoint_prefix = os.path.join(checkpoint_dir, model_dir)
logs_dir = os.path.join(logs_dir, model_dir)

# %% [markdown]
# ## Restore checkpoint & start train or test phase

# %%
if train_flag :

    checkpoint = tf.train.Checkpoint(dnn=network)

    # create writer for tensorboard
    summary_writer = tf.summary.create_file_writer(logdir=logs_dir)
    start_time = time()

    # restore check-point if it exits
    could_load, checkpoint_counter = load(network, checkpoint_dir)    

    if could_load:
        start_epoch = (int)(checkpoint_counter / training_iterations)        
        counter = checkpoint_counter        
        print(" [*] Load SUCCESS")
    else:
        start_epoch = 0
        start_iteration = 0
        counter = 0
        print(" [!] Load failed...")
    
    # train phase
    with summary_writer.as_default():  # for tensorboard
        for epoch in range(start_epoch, training_epochs):
            for idx, (train_input, train_label) in enumerate(train_dataset):            
                grads = grad(network, train_input, train_label)
                optimizer.apply_gradients(grads_and_vars=zip(grads, network.variables))

                train_loss = loss_fn(network, train_input, train_label)
                train_accuracy = accuracy_fn(network, train_input, train_label)
                
                for test_input, test_label in test_dataset:                
                    test_accuracy = accuracy_fn(network, test_input, test_label)

                tf.summary.scalar(name='train_loss', data=train_loss, step=counter)
                tf.summary.scalar(name='train_accuracy', data=train_accuracy, step=counter)
                tf.summary.scalar(name='test_accuracy', data=test_accuracy, step=counter)

                print(
                    "Epoch: [%2d] [%5d/%5d] time: %4.4f, train_loss: %.8f, train_accuracy: %.4f, test_Accuracy: %.4f" \
                    % (epoch, idx, training_iterations, time() - start_time, train_loss, train_accuracy,
                       test_accuracy))
                counter += 1                
        checkpoint.save(file_prefix=checkpoint_prefix + '-{}'.format(counter))
        
# test phase      
else :
    _, _ = load(network, checkpoint_dir)
    for test_input, test_label in test_dataset:    
        test_accuracy = accuracy_fn(network, test_input, test_label)

    print("test_Accuracy: %.4f" % (test_accuracy))
# Out:
#  [*] Reading checkpoints...
#  [*] Failed to find a checkpoint
#  [!] Load failed...
# Epoch: [ 0] [    0/  468] time: 0.4766, train_loss: 2.27644157, train_accuracy: 0.1094, test_Accuracy: 0.0964
# Epoch: [ 0] [    1/  468] time: 0.6190, train_loss: 2.27180529, train_accuracy: 0.1250, test_Accuracy: 0.0974
# Epoch: [ 0] [    2/  468] time: 0.7640, train_loss: 2.26133966, train_accuracy: 0.1250, test_Accuracy: 0.0994
# Epoch: [ 0] [    3/  468] time: 0.8896, train_loss: 2.29708242, train_accuracy: 0.1484, test_Accuracy: 0.1323
# Epoch: [ 0] [    4/  468] time: 1.0223, train_loss: 2.29229736, train_accuracy: 0.0938, test_Accuracy: 0.1029
# Epoch: [ 0] [    5/  468] time: 1.2670, train_loss: 2.22628808, train_accuracy: 0.1172, test_Accuracy: 0.1067
# Epoch: [ 0] [    6/  468] time: 1.4223, train_loss: 2.25746107, train_accuracy: 0.2344, test_Accuracy: 0.2497
# Epoch: [ 0] [    7/  468] time: 1.5541, train_loss: 2.24102616, train_accuracy: 0.1484, test_Accuracy: 0.1508
# Epoch: [ 0] [    8/  468] time: 1.6842, train_loss: 2.21663618, train_accuracy: 0.1797, test_Accuracy: 0.1125
# Epoch: [ 0] [    9/  468] time: 1.8183, train_loss: 2.19279671, train_accuracy: 0.1562, test_Accuracy: 0.1242
# Epoch: [ 0] [   10/  468] time: 1.9479, train_loss: 2.18583918, train_accuracy: 0.1953, test_Accuracy: 0.1295
# Epoch: [ 0] [   11/  468] time: 2.0822, train_loss: 2.20350599, train_accuracy: 0.1328, test_Accuracy: 0.1478
# Epoch: [ 0] [   12/  468] time: 2.2135, train_loss: 2.18917251, train_accuracy: 0.2266, test_Accuracy: 0.2489
# Epoch: [ 0] [   13/  468] time: 2.3465, train_loss: 2.16042995, train_accuracy: 0.3203, test_Accuracy: 0.3293
# Epoch: [ 0] [   14/  468] time: 2.4805, train_loss: 2.13823581, train_accuracy: 0.6016, test_Accuracy: 0.5744
# Epoch: [ 0] [   15/  468] time: 2.6137, train_loss: 2.10022902, train_accuracy: 0.5703, test_Accuracy: 0.5436
# Epoch: [ 0] [   16/  468] time: 2.7482, train_loss: 2.10745001, train_accuracy: 0.3984, test_Accuracy: 0.4373
# Epoch: [ 0] [   17/  468] time: 2.8811, train_loss: 2.07349658, train_accuracy: 0.4375, test_Accuracy: 0.3549
# Epoch: [ 0] [   18/  468] time: 3.0094, train_loss: 2.05199337, train_accuracy: 0.3594, test_Accuracy: 0.2828
# Epoch: [ 0] [   19/  468] time: 3.1445, train_loss: 2.07915664, train_accuracy: 0.2969, test_Accuracy: 0.2702
# Epoch: [ 0] [   20/  468] time: 3.2779, train_loss: 2.01798964, train_accuracy: 0.3672, test_Accuracy: 0.2700
# Epoch: [ 0] [   21/  468] time: 3.4113, train_loss: 2.02009058, train_accuracy: 0.2969, test_Accuracy: 0.2879
# Epoch: [ 0] [   22/  468] time: 3.5522, train_loss: 2.01004767, train_accuracy: 0.3516, test_Accuracy: 0.3230
# Epoch: [ 0] [   23/  468] time: 3.7018, train_loss: 2.03731251, train_accuracy: 0.3359, test_Accuracy: 0.3971
# Epoch: [ 0] [   24/  468] time: 3.8414, train_loss: 1.99659324, train_accuracy: 0.4141, test_Accuracy: 0.4957
# Epoch: [ 0] [   25/  468] time: 3.9907, train_loss: 1.94065058, train_accuracy: 0.5312, test_Accuracy: 0.5523
# Epoch: [ 0] [   26/  468] time: 4.1319, train_loss: 1.93800581, train_accuracy: 0.5234, test_Accuracy: 0.5805
# Epoch: [ 0] [   27/  468] time: 4.2693, train_loss: 1.86522901, train_accuracy: 0.6172, test_Accuracy: 0.5760
# Epoch: [ 0] [   28/  468] time: 4.4076, train_loss: 1.81764221, train_accuracy: 0.6250, test_Accuracy: 0.5638
# Epoch: [ 0] [   29/  468] time: 4.5487, train_loss: 1.85814166, train_accuracy: 0.4922, test_Accuracy: 0.5596
# Epoch: [ 0] [   30/  468] time: 4.6940, train_loss: 1.83989859, train_accuracy: 0.5703, test_Accuracy: 0.5578
# Epoch: [ 0] [   31/  468] time: 4.8682, train_loss: 1.80466366, train_accuracy: 0.5781, test_Accuracy: 0.5626
# Epoch: [ 0] [   32/  468] time: 5.0298, train_loss: 1.77846158, train_accuracy: 0.5625, test_Accuracy: 0.5851
# Epoch: [ 0] [   33/  468] time: 5.1941, train_loss: 1.77499628, train_accuracy: 0.6328, test_Accuracy: 0.6089
# Epoch: [ 0] [   34/  468] time: 5.4051, train_loss: 1.71254158, train_accuracy: 0.6094, test_Accuracy: 0.6154
# Epoch: [ 0] [   35/  468] time: 5.5832, train_loss: 1.66281486, train_accuracy: 0.6641, test_Accuracy: 0.6234
# Epoch: [ 0] [   36/  468] time: 5.7219, train_loss: 1.61817193, train_accuracy: 0.6484, test_Accuracy: 0.6348
# Epoch: [ 0] [   37/  468] time: 5.8569, train_loss: 1.60299373, train_accuracy: 0.6562, test_Accuracy: 0.6293
# Epoch: [ 0] [   38/  468] time: 6.0065, train_loss: 1.57821608, train_accuracy: 0.6406, test_Accuracy: 0.6063
# Epoch: [ 0] [   39/  468] time: 6.1677, train_loss: 1.67597508, train_accuracy: 0.5625, test_Accuracy: 0.6059
# Epoch: [ 0] [   40/  468] time: 6.3307, train_loss: 1.59406388, train_accuracy: 0.6172, test_Accuracy: 0.6010
# Epoch: [ 0] [   41/  468] time: 6.4917, train_loss: 1.53936291, train_accuracy: 0.5859, test_Accuracy: 0.6003
# Epoch: [ 0] [   42/  468] time: 6.6465, train_loss: 1.43277860, train_accuracy: 0.6406, test_Accuracy: 0.6049
# Epoch: [ 0] [   43/  468] time: 6.7793, train_loss: 1.51113653, train_accuracy: 0.5938, test_Accuracy: 0.6217
# Epoch: [ 0] [   44/  468] time: 6.9247, train_loss: 1.45461047, train_accuracy: 0.6641, test_Accuracy: 0.6351
# Epoch: [ 0] [   45/  468] time: 7.0791, train_loss: 1.40992379, train_accuracy: 0.6641, test_Accuracy: 0.6401
# Epoch: [ 0] [   46/  468] time: 7.2315, train_loss: 1.41120625, train_accuracy: 0.6953, test_Accuracy: 0.6318
# Epoch: [ 0] [   47/  468] time: 7.3852, train_loss: 1.40924335, train_accuracy: 0.6250, test_Accuracy: 0.6252
# Epoch: [ 0] [   48/  468] time: 7.5309, train_loss: 1.38263512, train_accuracy: 0.7188, test_Accuracy: 0.6162
# Epoch: [ 0] [   49/  468] time: 7.6737, train_loss: 1.37013078, train_accuracy: 0.6094, test_Accuracy: 0.6159
# Epoch: [ 0] [   50/  468] time: 7.8350, train_loss: 1.33847523, train_accuracy: 0.6016, test_Accuracy: 0.6270
# Epoch: [ 0] [   51/  468] time: 8.0231, train_loss: 1.18872583, train_accuracy: 0.7500, test_Accuracy: 0.6354
# Epoch: [ 0] [   52/  468] time: 8.1978, train_loss: 1.24050128, train_accuracy: 0.6719, test_Accuracy: 0.6489
# Epoch: [ 0] [   53/  468] time: 8.3365, train_loss: 1.26892900, train_accuracy: 0.6484, test_Accuracy: 0.6697
# Epoch: [ 0] [   54/  468] time: 8.4823, train_loss: 1.18158472, train_accuracy: 0.7422, test_Accuracy: 0.6832
# Epoch: [ 0] [   55/  468] time: 8.6346, train_loss: 1.16091752, train_accuracy: 0.7109, test_Accuracy: 0.7005
# Epoch: [ 0] [   56/  468] time: 8.7815, train_loss: 1.27869964, train_accuracy: 0.6953, test_Accuracy: 0.7157
# Epoch: [ 0] [   57/  468] time: 8.9360, train_loss: 1.17320943, train_accuracy: 0.7344, test_Accuracy: 0.7268
# Epoch: [ 0] [   58/  468] time: 9.1091, train_loss: 1.15110469, train_accuracy: 0.7422, test_Accuracy: 0.7350
# Epoch: [ 0] [   59/  468] time: 9.2962, train_loss: 1.11826801, train_accuracy: 0.7344, test_Accuracy: 0.7492
# Epoch: [ 0] [   60/  468] time: 9.4733, train_loss: 1.17350841, train_accuracy: 0.7109, test_Accuracy: 0.7662
# Epoch: [ 0] [   61/  468] time: 9.6429, train_loss: 1.12136221, train_accuracy: 0.7500, test_Accuracy: 0.7746
# Epoch: [ 0] [   62/  468] time: 9.8610, train_loss: 1.07424271, train_accuracy: 0.7969, test_Accuracy: 0.7715
# Epoch: [ 0] [   63/  468] time: 10.0273, train_loss: 1.10755277, train_accuracy: 0.7500, test_Accuracy: 0.7663
# Epoch: [ 0] [   64/  468] time: 10.1878, train_loss: 1.03941131, train_accuracy: 0.7969, test_Accuracy: 0.7557
# Epoch: [ 0] [   65/  468] time: 10.3461, train_loss: 1.02382100, train_accuracy: 0.7578, test_Accuracy: 0.7528
# Epoch: [ 0] [   66/  468] time: 10.5001, train_loss: 1.01460433, train_accuracy: 0.7422, test_Accuracy: 0.7600
# Epoch: [ 0] [   67/  468] time: 10.6850, train_loss: 1.04122412, train_accuracy: 0.8125, test_Accuracy: 0.7705
# Epoch: [ 0] [   68/  468] time: 10.8694, train_loss: 0.95560229, train_accuracy: 0.7656, test_Accuracy: 0.7844
# Epoch: [ 0] [   69/  468] time: 11.0068, train_loss: 0.99686658, train_accuracy: 0.7734, test_Accuracy: 0.7933
# Epoch: [ 0] [   70/  468] time: 11.1710, train_loss: 0.92757714, train_accuracy: 0.7969, test_Accuracy: 0.7886
# Epoch: [ 0] [   71/  468] time: 11.3240, train_loss: 0.99349427, train_accuracy: 0.7734, test_Accuracy: 0.7734
# Epoch: [ 0] [   72/  468] time: 11.4764, train_loss: 0.85076380, train_accuracy: 0.8047, test_Accuracy: 0.7615
# Epoch: [ 0] [   73/  468] time: 11.6270, train_loss: 0.91818321, train_accuracy: 0.8281, test_Accuracy: 0.7506
# Epoch: [ 0] [   74/  468] time: 11.7756, train_loss: 0.89852166, train_accuracy: 0.7422, test_Accuracy: 0.7478
# Epoch: [ 0] [   75/  468] time: 11.9124, train_loss: 0.85998750, train_accuracy: 0.7656, test_Accuracy: 0.7487
# Epoch: [ 0] [   76/  468] time: 12.0498, train_loss: 0.98872328, train_accuracy: 0.7344, test_Accuracy: 0.7617
# Epoch: [ 0] [   77/  468] time: 12.1823, train_loss: 0.93742210, train_accuracy: 0.7266, test_Accuracy: 0.7764
# Epoch: [ 0] [   78/  468] time: 12.3174, train_loss: 0.86053902, train_accuracy: 0.8203, test_Accuracy: 0.7924
# Epoch: [ 0] [   79/  468] time: 12.4526, train_loss: 0.92622340, train_accuracy: 0.7422, test_Accuracy: 0.8096
# Epoch: [ 0] [   80/  468] time: 12.5875, train_loss: 0.87209749, train_accuracy: 0.7969, test_Accuracy: 0.8200
# Epoch: [ 0] [   81/  468] time: 12.7251, train_loss: 0.80926228, train_accuracy: 0.8672, test_Accuracy: 0.8261
# Epoch: [ 0] [   82/  468] time: 12.8624, train_loss: 0.83675945, train_accuracy: 0.8359, test_Accuracy: 0.8248
# Epoch: [ 0] [   83/  468] time: 12.9956, train_loss: 0.91435266, train_accuracy: 0.8047, test_Accuracy: 0.8231
# Epoch: [ 0] [   84/  468] time: 13.1269, train_loss: 0.76109815, train_accuracy: 0.8359, test_Accuracy: 0.8189
# Epoch: [ 0] [   85/  468] time: 13.2613, train_loss: 0.85795802, train_accuracy: 0.8047, test_Accuracy: 0.8213
# Epoch: [ 0] [   86/  468] time: 13.4004, train_loss: 0.83913541, train_accuracy: 0.7734, test_Accuracy: 0.8212
# Epoch: [ 0] [   87/  468] time: 13.5331, train_loss: 0.98861480, train_accuracy: 0.7422, test_Accuracy: 0.8262
# Epoch: [ 0] [   88/  468] time: 13.6728, train_loss: 0.79950607, train_accuracy: 0.8359, test_Accuracy: 0.8297
# Epoch: [ 0] [   89/  468] time: 13.8221, train_loss: 0.77608097, train_accuracy: 0.7812, test_Accuracy: 0.8290
# Epoch: [ 0] [   90/  468] time: 13.9672, train_loss: 0.68983316, train_accuracy: 0.8438, test_Accuracy: 0.8300
# Epoch: [ 0] [   91/  468] time: 14.1055, train_loss: 0.72221816, train_accuracy: 0.8750, test_Accuracy: 0.8294
# Epoch: [ 0] [   92/  468] time: 14.2416, train_loss: 0.67872155, train_accuracy: 0.8750, test_Accuracy: 0.8274
# Epoch: [ 0] [   93/  468] time: 14.4029, train_loss: 0.72728837, train_accuracy: 0.8438, test_Accuracy: 0.8265
# Epoch: [ 0] [   94/  468] time: 14.5688, train_loss: 0.80249095, train_accuracy: 0.8047, test_Accuracy: 0.8255
# Epoch: [ 0] [   95/  468] time: 14.7115, train_loss: 0.67563903, train_accuracy: 0.8828, test_Accuracy: 0.8273
# Epoch: [ 0] [   96/  468] time: 14.8569, train_loss: 0.73296058, train_accuracy: 0.8281, test_Accuracy: 0.8310
# Epoch: [ 0] [   97/  468] time: 15.0165, train_loss: 0.84015292, train_accuracy: 0.7812, test_Accuracy: 0.8356
# Epoch: [ 0] [   98/  468] time: 15.2064, train_loss: 0.69368696, train_accuracy: 0.8203, test_Accuracy: 0.8405
# Epoch: [ 0] [   99/  468] time: 15.3838, train_loss: 0.62251496, train_accuracy: 0.8516, test_Accuracy: 0.8444
# Epoch: [ 0] [  100/  468] time: 15.5530, train_loss: 0.74675107, train_accuracy: 0.7891, test_Accuracy: 0.8452
# Epoch: [ 0] [  101/  468] time: 15.6963, train_loss: 0.59561056, train_accuracy: 0.8672, test_Accuracy: 0.8441
# Epoch: [ 0] [  102/  468] time: 15.9216, train_loss: 0.66504437, train_accuracy: 0.8516, test_Accuracy: 0.8430
# Epoch: [ 0] [  103/  468] time: 16.1029, train_loss: 0.71656018, train_accuracy: 0.8516, test_Accuracy: 0.8390
# Epoch: [ 0] [  104/  468] time: 16.2865, train_loss: 0.68980932, train_accuracy: 0.8594, test_Accuracy: 0.8369
# Epoch: [ 0] [  105/  468] time: 16.4541, train_loss: 0.59340811, train_accuracy: 0.8594, test_Accuracy: 0.8346
# Epoch: [ 0] [  106/  468] time: 16.8521, train_loss: 0.71240044, train_accuracy: 0.8047, test_Accuracy: 0.8369
# Epoch: [ 0] [  107/  468] time: 17.0535, train_loss: 0.51739490, train_accuracy: 0.9062, test_Accuracy: 0.8374
# Epoch: [ 0] [  108/  468] time: 17.2992, train_loss: 0.67479110, train_accuracy: 0.8281, test_Accuracy: 0.8388
# Epoch: [ 0] [  109/  468] time: 17.4872, train_loss: 0.49830687, train_accuracy: 0.9141, test_Accuracy: 0.8408
# Epoch: [ 0] [  110/  468] time: 17.6708, train_loss: 0.65733993, train_accuracy: 0.8203, test_Accuracy: 0.8437
# Epoch: [ 0] [  111/  468] time: 17.8450, train_loss: 0.65797228, train_accuracy: 0.8672, test_Accuracy: 0.8486
# Epoch: [ 0] [  112/  468] time: 18.0402, train_loss: 0.56157756, train_accuracy: 0.8516, test_Accuracy: 0.8499
# Epoch: [ 0] [  113/  468] time: 18.2168, train_loss: 0.52755618, train_accuracy: 0.8672, test_Accuracy: 0.8522
# Epoch: [ 0] [  114/  468] time: 18.3762, train_loss: 0.55513448, train_accuracy: 0.8594, test_Accuracy: 0.8559
# Epoch: [ 0] [  115/  468] time: 18.5354, train_loss: 0.54623282, train_accuracy: 0.8750, test_Accuracy: 0.8569
# Epoch: [ 0] [  116/  468] time: 18.6966, train_loss: 0.62797207, train_accuracy: 0.8203, test_Accuracy: 0.8590
# Epoch: [ 0] [  117/  468] time: 18.8438, train_loss: 0.63428324, train_accuracy: 0.8359, test_Accuracy: 0.8613
# Epoch: [ 0] [  118/  468] time: 18.9841, train_loss: 0.65651929, train_accuracy: 0.8750, test_Accuracy: 0.8639
# Epoch: [ 0] [  119/  468] time: 19.1255, train_loss: 0.53178090, train_accuracy: 0.8906, test_Accuracy: 0.8642
# Epoch: [ 0] [  120/  468] time: 19.2816, train_loss: 0.56277823, train_accuracy: 0.8750, test_Accuracy: 0.8636
# Epoch: [ 0] [  121/  468] time: 19.4279, train_loss: 0.60004324, train_accuracy: 0.8594, test_Accuracy: 0.8625
# Epoch: [ 0] [  122/  468] time: 19.5864, train_loss: 0.53418761, train_accuracy: 0.8516, test_Accuracy: 0.8624
# Epoch: [ 0] [  123/  468] time: 19.7286, train_loss: 0.58061731, train_accuracy: 0.8438, test_Accuracy: 0.8647
# Epoch: [ 0] [  124/  468] time: 19.8740, train_loss: 0.51868773, train_accuracy: 0.9062, test_Accuracy: 0.8646
# Epoch: [ 0] [  125/  468] time: 20.0208, train_loss: 0.60787272, train_accuracy: 0.8750, test_Accuracy: 0.8655
# Epoch: [ 0] [  126/  468] time: 20.1693, train_loss: 0.54532719, train_accuracy: 0.8828, test_Accuracy: 0.8660
# Epoch: [ 0] [  127/  468] time: 20.3226, train_loss: 0.58530980, train_accuracy: 0.8516, test_Accuracy: 0.8660
# Epoch: [ 0] [  128/  468] time: 20.4573, train_loss: 0.57688117, train_accuracy: 0.8594, test_Accuracy: 0.8624
# Epoch: [ 0] [  129/  468] time: 20.5987, train_loss: 0.54486394, train_accuracy: 0.8359, test_Accuracy: 0.8613
# Epoch: [ 0] [  130/  468] time: 20.7424, train_loss: 0.50709158, train_accuracy: 0.8828, test_Accuracy: 0.8609
# Epoch: [ 0] [  131/  468] time: 20.9019, train_loss: 0.60806906, train_accuracy: 0.8281, test_Accuracy: 0.8606
# Epoch: [ 0] [  132/  468] time: 21.0561, train_loss: 0.54207432, train_accuracy: 0.8672, test_Accuracy: 0.8623
# Epoch: [ 0] [  133/  468] time: 21.2005, train_loss: 0.46892723, train_accuracy: 0.8984, test_Accuracy: 0.8647
# Epoch: [ 0] [  134/  468] time: 21.3385, train_loss: 0.52119070, train_accuracy: 0.8594, test_Accuracy: 0.8654
# Epoch: [ 0] [  135/  468] time: 21.4851, train_loss: 0.53078449, train_accuracy: 0.8750, test_Accuracy: 0.8669
# Epoch: [ 0] [  136/  468] time: 21.6311, train_loss: 0.53257787, train_accuracy: 0.8906, test_Accuracy: 0.8686
# Epoch: [ 0] [  137/  468] time: 21.7778, train_loss: 0.49799746, train_accuracy: 0.8984, test_Accuracy: 0.8729
# Epoch: [ 0] [  138/  468] time: 21.9085, train_loss: 0.52031678, train_accuracy: 0.8438, test_Accuracy: 0.8738
# Epoch: [ 0] [  139/  468] time: 22.0423, train_loss: 0.54784024, train_accuracy: 0.8516, test_Accuracy: 0.8758
# Epoch: [ 0] [  140/  468] time: 22.1867, train_loss: 0.48992842, train_accuracy: 0.8984, test_Accuracy: 0.8760
# Epoch: [ 0] [  141/  468] time: 22.3231, train_loss: 0.48334000, train_accuracy: 0.9219, test_Accuracy: 0.8767
# Epoch: [ 0] [  142/  468] time: 22.4555, train_loss: 0.53095740, train_accuracy: 0.8672, test_Accuracy: 0.8740
# Epoch: [ 0] [  143/  468] time: 22.6222, train_loss: 0.43046004, train_accuracy: 0.8906, test_Accuracy: 0.8746
# Epoch: [ 0] [  144/  468] time: 22.7633, train_loss: 0.50947130, train_accuracy: 0.8594, test_Accuracy: 0.8743
# Epoch: [ 0] [  145/  468] time: 22.9103, train_loss: 0.45845819, train_accuracy: 0.8828, test_Accuracy: 0.8751
# Epoch: [ 0] [  146/  468] time: 23.0509, train_loss: 0.49442500, train_accuracy: 0.8672, test_Accuracy: 0.8775
# Epoch: [ 0] [  147/  468] time: 23.1935, train_loss: 0.57129025, train_accuracy: 0.8594, test_Accuracy: 0.8787
# Epoch: [ 0] [  148/  468] time: 23.3588, train_loss: 0.48893341, train_accuracy: 0.8438, test_Accuracy: 0.8805
# Epoch: [ 0] [  149/  468] time: 23.5727, train_loss: 0.35893574, train_accuracy: 0.9297, test_Accuracy: 0.8808
# Epoch: [ 0] [  150/  468] time: 23.7275, train_loss: 0.44650680, train_accuracy: 0.8750, test_Accuracy: 0.8809
# Epoch: [ 0] [  151/  468] time: 23.9116, train_loss: 0.46599239, train_accuracy: 0.9062, test_Accuracy: 0.8802
# Epoch: [ 0] [  152/  468] time: 24.0935, train_loss: 0.47476560, train_accuracy: 0.8750, test_Accuracy: 0.8786
# Epoch: [ 0] [  153/  468] time: 24.2626, train_loss: 0.42078698, train_accuracy: 0.8906, test_Accuracy: 0.8794
# Epoch: [ 0] [  154/  468] time: 24.4074, train_loss: 0.47136265, train_accuracy: 0.8594, test_Accuracy: 0.8803
# Epoch: [ 0] [  155/  468] time: 24.5768, train_loss: 0.50948435, train_accuracy: 0.8359, test_Accuracy: 0.8799
# Epoch: [ 0] [  156/  468] time: 24.7425, train_loss: 0.37858343, train_accuracy: 0.8906, test_Accuracy: 0.8818
# Epoch: [ 0] [  157/  468] time: 24.9188, train_loss: 0.47726440, train_accuracy: 0.8828, test_Accuracy: 0.8825
# Epoch: [ 0] [  158/  468] time: 25.0691, train_loss: 0.49761406, train_accuracy: 0.8359, test_Accuracy: 0.8844
# Epoch: [ 0] [  159/  468] time: 25.2356, train_loss: 0.57927346, train_accuracy: 0.8516, test_Accuracy: 0.8855
# Epoch: [ 0] [  160/  468] time: 25.4105, train_loss: 0.38338906, train_accuracy: 0.9219, test_Accuracy: 0.8858
# Epoch: [ 0] [  161/  468] time: 25.5745, train_loss: 0.42627662, train_accuracy: 0.9141, test_Accuracy: 0.8835
# Epoch: [ 0] [  162/  468] time: 25.7750, train_loss: 0.50867379, train_accuracy: 0.8359, test_Accuracy: 0.8833
# Epoch: [ 0] [  163/  468] time: 26.0125, train_loss: 0.53227282, train_accuracy: 0.8047, test_Accuracy: 0.8812
# Epoch: [ 0] [  164/  468] time: 26.1959, train_loss: 0.39736980, train_accuracy: 0.9297, test_Accuracy: 0.8816
# Epoch: [ 0] [  165/  468] time: 26.4129, train_loss: 0.33771122, train_accuracy: 0.9219, test_Accuracy: 0.8823
# Epoch: [ 0] [  166/  468] time: 26.5903, train_loss: 0.41616595, train_accuracy: 0.9062, test_Accuracy: 0.8833
# Epoch: [ 0] [  167/  468] time: 26.7731, train_loss: 0.55082184, train_accuracy: 0.8672, test_Accuracy: 0.8848
# Epoch: [ 0] [  168/  468] time: 26.9143, train_loss: 0.38410830, train_accuracy: 0.9141, test_Accuracy: 0.8869
# Epoch: [ 0] [  169/  468] time: 27.0608, train_loss: 0.46736547, train_accuracy: 0.8672, test_Accuracy: 0.8878
# Epoch: [ 0] [  170/  468] time: 27.2132, train_loss: 0.50817549, train_accuracy: 0.8359, test_Accuracy: 0.8883
# Epoch: [ 0] [  171/  468] time: 27.3635, train_loss: 0.47430450, train_accuracy: 0.8750, test_Accuracy: 0.8880
# Epoch: [ 0] [  172/  468] time: 27.5006, train_loss: 0.44727182, train_accuracy: 0.8750, test_Accuracy: 0.8865
# Epoch: [ 0] [  173/  468] time: 27.6584, train_loss: 0.32732448, train_accuracy: 0.9141, test_Accuracy: 0.8866
# Epoch: [ 0] [  174/  468] time: 27.8117, train_loss: 0.42334008, train_accuracy: 0.9062, test_Accuracy: 0.8863
# Epoch: [ 0] [  175/  468] time: 27.9971, train_loss: 0.46552902, train_accuracy: 0.8750, test_Accuracy: 0.8871
# Epoch: [ 0] [  176/  468] time: 28.1472, train_loss: 0.33312625, train_accuracy: 0.9297, test_Accuracy: 0.8880
# Epoch: [ 0] [  177/  468] time: 28.2987, train_loss: 0.38687402, train_accuracy: 0.9062, test_Accuracy: 0.8884
# Epoch: [ 0] [  178/  468] time: 28.4464, train_loss: 0.39830881, train_accuracy: 0.9062, test_Accuracy: 0.8887
# Epoch: [ 0] [  179/  468] time: 28.6394, train_loss: 0.42200607, train_accuracy: 0.8984, test_Accuracy: 0.8902
# Epoch: [ 0] [  180/  468] time: 28.8252, train_loss: 0.46795917, train_accuracy: 0.8828, test_Accuracy: 0.8914
# Epoch: [ 0] [  181/  468] time: 29.0189, train_loss: 0.42594680, train_accuracy: 0.8672, test_Accuracy: 0.8905
# Epoch: [ 0] [  182/  468] time: 29.2118, train_loss: 0.39900240, train_accuracy: 0.8828, test_Accuracy: 0.8919
# Epoch: [ 0] [  183/  468] time: 29.4362, train_loss: 0.47334462, train_accuracy: 0.8906, test_Accuracy: 0.8926
# Epoch: [ 0] [  184/  468] time: 29.6269, train_loss: 0.46023792, train_accuracy: 0.8750, test_Accuracy: 0.8916
# Epoch: [ 0] [  185/  468] time: 29.7928, train_loss: 0.30704355, train_accuracy: 0.9375, test_Accuracy: 0.8896
# Epoch: [ 0] [  186/  468] time: 29.9306, train_loss: 0.58581293, train_accuracy: 0.8047, test_Accuracy: 0.8896
# Epoch: [ 0] [  187/  468] time: 30.0664, train_loss: 0.46550208, train_accuracy: 0.8828, test_Accuracy: 0.8911
# Epoch: [ 0] [  188/  468] time: 30.2006, train_loss: 0.39717332, train_accuracy: 0.8984, test_Accuracy: 0.8933
# Epoch: [ 0] [  189/  468] time: 30.3655, train_loss: 0.37732074, train_accuracy: 0.8906, test_Accuracy: 0.8944
# Epoch: [ 0] [  190/  468] time: 30.5259, train_loss: 0.42617163, train_accuracy: 0.9062, test_Accuracy: 0.8964
# Epoch: [ 0] [  191/  468] time: 30.6711, train_loss: 0.35161385, train_accuracy: 0.8984, test_Accuracy: 0.8971
# Epoch: [ 0] [  192/  468] time: 30.8056, train_loss: 0.32281721, train_accuracy: 0.9531, test_Accuracy: 0.8959
# Epoch: [ 0] [  193/  468] time: 31.0186, train_loss: 0.48699853, train_accuracy: 0.8438, test_Accuracy: 0.8952
# Epoch: [ 0] [  194/  468] time: 31.1831, train_loss: 0.49735463, train_accuracy: 0.8516, test_Accuracy: 0.8949
# Epoch: [ 0] [  195/  468] time: 31.3999, train_loss: 0.32075244, train_accuracy: 0.9219, test_Accuracy: 0.8942
# Epoch: [ 0] [  196/  468] time: 31.5449, train_loss: 0.35248482, train_accuracy: 0.9141, test_Accuracy: 0.8933
# Epoch: [ 0] [  197/  468] time: 31.8132, train_loss: 0.42590573, train_accuracy: 0.8750, test_Accuracy: 0.8926
# Epoch: [ 0] [  198/  468] time: 32.0306, train_loss: 0.33579329, train_accuracy: 0.8984, test_Accuracy: 0.8932
# Epoch: [ 0] [  199/  468] time: 32.2251, train_loss: 0.26217502, train_accuracy: 0.9453, test_Accuracy: 0.8943
# Epoch: [ 0] [  200/  468] time: 32.4131, train_loss: 0.37265119, train_accuracy: 0.8750, test_Accuracy: 0.8955
# Epoch: [ 0] [  201/  468] time: 32.5577, train_loss: 0.36006629, train_accuracy: 0.9141, test_Accuracy: 0.8961
# Epoch: [ 0] [  202/  468] time: 32.6950, train_loss: 0.42658091, train_accuracy: 0.8906, test_Accuracy: 0.8977
# Epoch: [ 0] [  203/  468] time: 32.8512, train_loss: 0.43077040, train_accuracy: 0.8984, test_Accuracy: 0.8993
# Epoch: [ 0] [  204/  468] time: 33.0085, train_loss: 0.33009550, train_accuracy: 0.9219, test_Accuracy: 0.8988
# Epoch: [ 0] [  205/  468] time: 33.1765, train_loss: 0.46355987, train_accuracy: 0.8672, test_Accuracy: 0.8988
# Epoch: [ 0] [  206/  468] time: 33.3581, train_loss: 0.35767591, train_accuracy: 0.8828, test_Accuracy: 0.8976
# Epoch: [ 0] [  207/  468] time: 33.5255, train_loss: 0.43345982, train_accuracy: 0.8828, test_Accuracy: 0.8969
# Epoch: [ 0] [  208/  468] time: 33.6660, train_loss: 0.44621164, train_accuracy: 0.8906, test_Accuracy: 0.8960
# Epoch: [ 0] [  209/  468] time: 33.8074, train_loss: 0.44678047, train_accuracy: 0.8438, test_Accuracy: 0.8957
# Epoch: [ 0] [  210/  468] time: 33.9657, train_loss: 0.39664713, train_accuracy: 0.9062, test_Accuracy: 0.8947
# Epoch: [ 0] [  211/  468] time: 34.1281, train_loss: 0.34376258, train_accuracy: 0.9375, test_Accuracy: 0.8952
# Epoch: [ 0] [  212/  468] time: 34.2687, train_loss: 0.48524439, train_accuracy: 0.8594, test_Accuracy: 0.8962
# Epoch: [ 0] [  213/  468] time: 34.4444, train_loss: 0.29558927, train_accuracy: 0.9375, test_Accuracy: 0.8969
# Epoch: [ 0] [  214/  468] time: 34.5918, train_loss: 0.38120261, train_accuracy: 0.8906, test_Accuracy: 0.8979
# Epoch: [ 0] [  215/  468] time: 34.7433, train_loss: 0.36093384, train_accuracy: 0.9062, test_Accuracy: 0.8995
# Epoch: [ 0] [  216/  468] time: 34.9046, train_loss: 0.37988585, train_accuracy: 0.8672, test_Accuracy: 0.9015
# Epoch: [ 0] [  217/  468] time: 35.0859, train_loss: 0.36077213, train_accuracy: 0.9062, test_Accuracy: 0.9027
# Epoch: [ 0] [  218/  468] time: 35.2713, train_loss: 0.42993140, train_accuracy: 0.8828, test_Accuracy: 0.9023
# Epoch: [ 0] [  219/  468] time: 35.4685, train_loss: 0.41591257, train_accuracy: 0.9062, test_Accuracy: 0.9016
# Epoch: [ 0] [  220/  468] time: 35.6679, train_loss: 0.36612624, train_accuracy: 0.9141, test_Accuracy: 0.8983
# Epoch: [ 0] [  221/  468] time: 35.9253, train_loss: 0.40805903, train_accuracy: 0.8672, test_Accuracy: 0.8981
# Epoch: [ 0] [  222/  468] time: 36.0908, train_loss: 0.40372729, train_accuracy: 0.8828, test_Accuracy: 0.8981
# Epoch: [ 0] [  223/  468] time: 36.2393, train_loss: 0.40236720, train_accuracy: 0.8906, test_Accuracy: 0.9004
# Epoch: [ 0] [  224/  468] time: 36.3759, train_loss: 0.40855572, train_accuracy: 0.8906, test_Accuracy: 0.9012
# Epoch: [ 0] [  225/  468] time: 36.5820, train_loss: 0.40021732, train_accuracy: 0.8906, test_Accuracy: 0.9010
# Epoch: [ 0] [  226/  468] time: 36.7335, train_loss: 0.37764293, train_accuracy: 0.8906, test_Accuracy: 0.9015
# Epoch: [ 0] [  227/  468] time: 36.8958, train_loss: 0.37044814, train_accuracy: 0.8984, test_Accuracy: 0.9032
# Epoch: [ 0] [  228/  468] time: 37.0368, train_loss: 0.35951668, train_accuracy: 0.8984, test_Accuracy: 0.9028
# Epoch: [ 0] [  229/  468] time: 37.1718, train_loss: 0.43902820, train_accuracy: 0.9141, test_Accuracy: 0.9037
# Epoch: [ 0] [  230/  468] time: 37.3039, train_loss: 0.34029564, train_accuracy: 0.8906, test_Accuracy: 0.9044
# Epoch: [ 0] [  231/  468] time: 37.4389, train_loss: 0.51983291, train_accuracy: 0.8828, test_Accuracy: 0.9044
# Epoch: [ 0] [  232/  468] time: 37.5695, train_loss: 0.45654958, train_accuracy: 0.8672, test_Accuracy: 0.9036
# Epoch: [ 0] [  233/  468] time: 37.7020, train_loss: 0.33756083, train_accuracy: 0.8750, test_Accuracy: 0.9049
# Epoch: [ 0] [  234/  468] time: 37.8348, train_loss: 0.48722380, train_accuracy: 0.8516, test_Accuracy: 0.9058
# Epoch: [ 0] [  235/  468] time: 37.9672, train_loss: 0.39202940, train_accuracy: 0.8984, test_Accuracy: 0.9072
# Epoch: [ 0] [  236/  468] time: 38.0940, train_loss: 0.36319101, train_accuracy: 0.8984, test_Accuracy: 0.9070
# Epoch: [ 0] [  237/  468] time: 38.2295, train_loss: 0.37325716, train_accuracy: 0.8906, test_Accuracy: 0.9067
# Epoch: [ 0] [  238/  468] time: 38.3562, train_loss: 0.31819621, train_accuracy: 0.9375, test_Accuracy: 0.9067
# Epoch: [ 0] [  239/  468] time: 38.4911, train_loss: 0.36825278, train_accuracy: 0.8984, test_Accuracy: 0.9063
# Epoch: [ 0] [  240/  468] time: 38.6138, train_loss: 0.28780150, train_accuracy: 0.9375, test_Accuracy: 0.9066
# Epoch: [ 0] [  241/  468] time: 38.7453, train_loss: 0.38324219, train_accuracy: 0.8516, test_Accuracy: 0.9060
# Epoch: [ 0] [  242/  468] time: 38.8732, train_loss: 0.41954586, train_accuracy: 0.8984, test_Accuracy: 0.9068
# Epoch: [ 0] [  243/  468] time: 39.0080, train_loss: 0.40446675, train_accuracy: 0.8984, test_Accuracy: 0.9069
# Epoch: [ 0] [  244/  468] time: 39.1363, train_loss: 0.38031760, train_accuracy: 0.8984, test_Accuracy: 0.9069
# Epoch: [ 0] [  245/  468] time: 39.2695, train_loss: 0.32023013, train_accuracy: 0.8984, test_Accuracy: 0.9061
# Epoch: [ 0] [  246/  468] time: 39.3983, train_loss: 0.29697642, train_accuracy: 0.9453, test_Accuracy: 0.9042
# Epoch: [ 0] [  247/  468] time: 39.5296, train_loss: 0.34351486, train_accuracy: 0.9062, test_Accuracy: 0.9046
# Epoch: [ 0] [  248/  468] time: 39.6557, train_loss: 0.39720398, train_accuracy: 0.9062, test_Accuracy: 0.9034
# Epoch: [ 0] [  249/  468] time: 39.7907, train_loss: 0.41624939, train_accuracy: 0.9062, test_Accuracy: 0.9022
# Epoch: [ 0] [  250/  468] time: 39.9208, train_loss: 0.40668648, train_accuracy: 0.8984, test_Accuracy: 0.9027
# Epoch: [ 0] [  251/  468] time: 40.0551, train_loss: 0.38323268, train_accuracy: 0.8750, test_Accuracy: 0.9038
# Epoch: [ 0] [  252/  468] time: 40.1819, train_loss: 0.32277244, train_accuracy: 0.9062, test_Accuracy: 0.9035
# Epoch: [ 0] [  253/  468] time: 40.3174, train_loss: 0.36159199, train_accuracy: 0.8828, test_Accuracy: 0.9036
# Epoch: [ 0] [  254/  468] time: 40.4432, train_loss: 0.32174778, train_accuracy: 0.8828, test_Accuracy: 0.9052
# Epoch: [ 0] [  255/  468] time: 40.5729, train_loss: 0.38471824, train_accuracy: 0.8906, test_Accuracy: 0.9055
# Epoch: [ 0] [  256/  468] time: 40.7024, train_loss: 0.31629679, train_accuracy: 0.9219, test_Accuracy: 0.9055
# Epoch: [ 0] [  257/  468] time: 40.8381, train_loss: 0.27899221, train_accuracy: 0.9297, test_Accuracy: 0.9064
# Epoch: [ 0] [  258/  468] time: 40.9649, train_loss: 0.31662846, train_accuracy: 0.9297, test_Accuracy: 0.9066
# Epoch: [ 0] [  259/  468] time: 41.0962, train_loss: 0.33652645, train_accuracy: 0.9062, test_Accuracy: 0.9070
# Epoch: [ 0] [  260/  468] time: 41.2250, train_loss: 0.32848299, train_accuracy: 0.8984, test_Accuracy: 0.9074
# Epoch: [ 0] [  261/  468] time: 41.3582, train_loss: 0.33419079, train_accuracy: 0.8828, test_Accuracy: 0.9074
# Epoch: [ 0] [  262/  468] time: 41.4828, train_loss: 0.37139904, train_accuracy: 0.8672, test_Accuracy: 0.9075
# Epoch: [ 0] [  263/  468] time: 41.6127, train_loss: 0.33170408, train_accuracy: 0.8984, test_Accuracy: 0.9079
# Epoch: [ 0] [  264/  468] time: 41.7365, train_loss: 0.37206313, train_accuracy: 0.8906, test_Accuracy: 0.9079
# Epoch: [ 0] [  265/  468] time: 41.8654, train_loss: 0.47006565, train_accuracy: 0.8828, test_Accuracy: 0.9093
# Epoch: [ 0] [  266/  468] time: 42.0059, train_loss: 0.36670196, train_accuracy: 0.9297, test_Accuracy: 0.9093
# Epoch: [ 0] [  267/  468] time: 42.1363, train_loss: 0.34149748, train_accuracy: 0.9062, test_Accuracy: 0.9094
# Epoch: [ 0] [  268/  468] time: 42.2629, train_loss: 0.34264833, train_accuracy: 0.9219, test_Accuracy: 0.9099
# Epoch: [ 0] [  269/  468] time: 42.3963, train_loss: 0.26189676, train_accuracy: 0.9531, test_Accuracy: 0.9093
# Epoch: [ 0] [  270/  468] time: 42.5235, train_loss: 0.31807420, train_accuracy: 0.9219, test_Accuracy: 0.9083
# Epoch: [ 0] [  271/  468] time: 42.6538, train_loss: 0.34120345, train_accuracy: 0.9297, test_Accuracy: 0.9086
# Epoch: [ 0] [  272/  468] time: 42.7785, train_loss: 0.31411657, train_accuracy: 0.9219, test_Accuracy: 0.9084
# Epoch: [ 0] [  273/  468] time: 42.9057, train_loss: 0.40403080, train_accuracy: 0.8906, test_Accuracy: 0.9077
# Epoch: [ 0] [  274/  468] time: 43.0354, train_loss: 0.42020670, train_accuracy: 0.8984, test_Accuracy: 0.9086
# Epoch: [ 0] [  275/  468] time: 43.1639, train_loss: 0.25569907, train_accuracy: 0.9375, test_Accuracy: 0.9088
# Epoch: [ 0] [  276/  468] time: 43.2896, train_loss: 0.29652393, train_accuracy: 0.9375, test_Accuracy: 0.9089
# Epoch: [ 0] [  277/  468] time: 43.4178, train_loss: 0.23582989, train_accuracy: 0.9531, test_Accuracy: 0.9091
# Epoch: [ 0] [  278/  468] time: 43.5465, train_loss: 0.31226033, train_accuracy: 0.9062, test_Accuracy: 0.9090
# Epoch: [ 0] [  279/  468] time: 43.6796, train_loss: 0.46075207, train_accuracy: 0.8438, test_Accuracy: 0.9095
# Epoch: [ 0] [  280/  468] time: 43.8076, train_loss: 0.27881336, train_accuracy: 0.9219, test_Accuracy: 0.9103
# Epoch: [ 0] [  281/  468] time: 43.9388, train_loss: 0.36480337, train_accuracy: 0.9219, test_Accuracy: 0.9125
# Epoch: [ 0] [  282/  468] time: 44.0641, train_loss: 0.36096191, train_accuracy: 0.8984, test_Accuracy: 0.9133
# Epoch: [ 0] [  283/  468] time: 44.2034, train_loss: 0.36625341, train_accuracy: 0.8750, test_Accuracy: 0.9139
# Epoch: [ 0] [  284/  468] time: 44.3341, train_loss: 0.31002510, train_accuracy: 0.8906, test_Accuracy: 0.9138
# Epoch: [ 0] [  285/  468] time: 44.4642, train_loss: 0.36314929, train_accuracy: 0.9062, test_Accuracy: 0.9140
# Epoch: [ 0] [  286/  468] time: 44.5916, train_loss: 0.34050906, train_accuracy: 0.8984, test_Accuracy: 0.9138
# Epoch: [ 0] [  287/  468] time: 44.7222, train_loss: 0.25542632, train_accuracy: 0.9297, test_Accuracy: 0.9145
# Epoch: [ 0] [  288/  468] time: 44.8477, train_loss: 0.36327004, train_accuracy: 0.8906, test_Accuracy: 0.9126
# Epoch: [ 0] [  289/  468] time: 44.9741, train_loss: 0.27661759, train_accuracy: 0.9297, test_Accuracy: 0.9109
# Epoch: [ 0] [  290/  468] time: 45.1014, train_loss: 0.33894160, train_accuracy: 0.8984, test_Accuracy: 0.9099
# Epoch: [ 0] [  291/  468] time: 45.2318, train_loss: 0.29643482, train_accuracy: 0.9219, test_Accuracy: 0.9111
# Epoch: [ 0] [  292/  468] time: 45.3625, train_loss: 0.37948069, train_accuracy: 0.8594, test_Accuracy: 0.9129
# Epoch: [ 0] [  293/  468] time: 45.5004, train_loss: 0.31890553, train_accuracy: 0.9062, test_Accuracy: 0.9127
# Epoch: [ 0] [  294/  468] time: 45.6265, train_loss: 0.40521801, train_accuracy: 0.8984, test_Accuracy: 0.9123
# Epoch: [ 0] [  295/  468] time: 45.7625, train_loss: 0.26962891, train_accuracy: 0.9062, test_Accuracy: 0.9115
# Epoch: [ 0] [  296/  468] time: 45.8859, train_loss: 0.23724766, train_accuracy: 0.9375, test_Accuracy: 0.9105
# Epoch: [ 0] [  297/  468] time: 46.0183, train_loss: 0.22037825, train_accuracy: 0.9375, test_Accuracy: 0.9100
# Epoch: [ 0] [  298/  468] time: 46.1532, train_loss: 0.46603680, train_accuracy: 0.8438, test_Accuracy: 0.9090
# Epoch: [ 0] [  299/  468] time: 46.2861, train_loss: 0.34805456, train_accuracy: 0.8984, test_Accuracy: 0.9093
# Epoch: [ 0] [  300/  468] time: 46.4243, train_loss: 0.32425988, train_accuracy: 0.9062, test_Accuracy: 0.9095
# Epoch: [ 0] [  301/  468] time: 46.5548, train_loss: 0.33947116, train_accuracy: 0.8828, test_Accuracy: 0.9103
# Epoch: [ 0] [  302/  468] time: 46.6784, train_loss: 0.31817627, train_accuracy: 0.9062, test_Accuracy: 0.9104
# Epoch: [ 0] [  303/  468] time: 46.8077, train_loss: 0.27577418, train_accuracy: 0.9219, test_Accuracy: 0.9119
# Epoch: [ 0] [  304/  468] time: 46.9348, train_loss: 0.35332701, train_accuracy: 0.9219, test_Accuracy: 0.9123
# Epoch: [ 0] [  305/  468] time: 47.0643, train_loss: 0.26338348, train_accuracy: 0.9375, test_Accuracy: 0.9122
# Epoch: [ 0] [  306/  468] time: 47.1911, train_loss: 0.49494946, train_accuracy: 0.8906, test_Accuracy: 0.9120
# Epoch: [ 0] [  307/  468] time: 47.3231, train_loss: 0.26805794, train_accuracy: 0.9141, test_Accuracy: 0.9124
# Epoch: [ 0] [  308/  468] time: 47.4507, train_loss: 0.21903250, train_accuracy: 0.9219, test_Accuracy: 0.9140
# Epoch: [ 0] [  309/  468] time: 47.5808, train_loss: 0.28207985, train_accuracy: 0.9141, test_Accuracy: 0.9130
# Epoch: [ 0] [  310/  468] time: 47.7046, train_loss: 0.27999750, train_accuracy: 0.9141, test_Accuracy: 0.9115
# Epoch: [ 0] [  311/  468] time: 47.8386, train_loss: 0.28851092, train_accuracy: 0.9297, test_Accuracy: 0.9105
# Epoch: [ 0] [  312/  468] time: 47.9629, train_loss: 0.36802894, train_accuracy: 0.9141, test_Accuracy: 0.9108
# Epoch: [ 0] [  313/  468] time: 48.0897, train_loss: 0.35867280, train_accuracy: 0.8984, test_Accuracy: 0.9103
# Epoch: [ 0] [  314/  468] time: 48.2132, train_loss: 0.33834156, train_accuracy: 0.9062, test_Accuracy: 0.9111
# Epoch: [ 0] [  315/  468] time: 48.3480, train_loss: 0.22382696, train_accuracy: 0.9375, test_Accuracy: 0.9115
# Epoch: [ 0] [  316/  468] time: 48.4733, train_loss: 0.32998410, train_accuracy: 0.8984, test_Accuracy: 0.9133
# Epoch: [ 0] [  317/  468] time: 48.5983, train_loss: 0.32398123, train_accuracy: 0.9219, test_Accuracy: 0.9134
# Epoch: [ 0] [  318/  468] time: 48.7243, train_loss: 0.25092480, train_accuracy: 0.9453, test_Accuracy: 0.9149
# Epoch: [ 0] [  319/  468] time: 48.8628, train_loss: 0.20430130, train_accuracy: 0.9297, test_Accuracy: 0.9143
# Epoch: [ 0] [  320/  468] time: 48.9921, train_loss: 0.26081598, train_accuracy: 0.9375, test_Accuracy: 0.9146
# Epoch: [ 0] [  321/  468] time: 49.1222, train_loss: 0.30906293, train_accuracy: 0.9062, test_Accuracy: 0.9150
# Epoch: [ 0] [  322/  468] time: 49.2682, train_loss: 0.30363035, train_accuracy: 0.9062, test_Accuracy: 0.9154
# Epoch: [ 0] [  323/  468] time: 49.4325, train_loss: 0.34384891, train_accuracy: 0.9219, test_Accuracy: 0.9145
# Epoch: [ 0] [  324/  468] time: 49.5808, train_loss: 0.33755943, train_accuracy: 0.9062, test_Accuracy: 0.9149
# Epoch: [ 0] [  325/  468] time: 49.7354, train_loss: 0.30849028, train_accuracy: 0.9219, test_Accuracy: 0.9147
# Epoch: [ 0] [  326/  468] time: 49.8899, train_loss: 0.26711425, train_accuracy: 0.9141, test_Accuracy: 0.9152
# Epoch: [ 0] [  327/  468] time: 50.0350, train_loss: 0.30012241, train_accuracy: 0.8828, test_Accuracy: 0.9150
# Epoch: [ 0] [  328/  468] time: 50.1704, train_loss: 0.24211214, train_accuracy: 0.9375, test_Accuracy: 0.9161
# Epoch: [ 0] [  329/  468] time: 50.3021, train_loss: 0.19902219, train_accuracy: 0.9453, test_Accuracy: 0.9161
# Epoch: [ 0] [  330/  468] time: 50.4407, train_loss: 0.28979144, train_accuracy: 0.9375, test_Accuracy: 0.9169
# Epoch: [ 0] [  331/  468] time: 50.6283, train_loss: 0.23032126, train_accuracy: 0.9375, test_Accuracy: 0.9175
# Epoch: [ 0] [  332/  468] time: 50.7806, train_loss: 0.29256421, train_accuracy: 0.8984, test_Accuracy: 0.9168
# Epoch: [ 0] [  333/  468] time: 50.9357, train_loss: 0.38499838, train_accuracy: 0.8672, test_Accuracy: 0.9162
# Epoch: [ 0] [  334/  468] time: 51.1080, train_loss: 0.23423690, train_accuracy: 0.9219, test_Accuracy: 0.9150
# Epoch: [ 0] [  335/  468] time: 51.2606, train_loss: 0.27118659, train_accuracy: 0.9297, test_Accuracy: 0.9156
# Epoch: [ 0] [  336/  468] time: 51.4080, train_loss: 0.37995937, train_accuracy: 0.8984, test_Accuracy: 0.9153
# Epoch: [ 0] [  337/  468] time: 51.6002, train_loss: 0.27008221, train_accuracy: 0.9219, test_Accuracy: 0.9154
# Epoch: [ 0] [  338/  468] time: 51.7562, train_loss: 0.28126562, train_accuracy: 0.9219, test_Accuracy: 0.9149
# Epoch: [ 0] [  339/  468] time: 51.9081, train_loss: 0.32437253, train_accuracy: 0.9297, test_Accuracy: 0.9163
# Epoch: [ 0] [  340/  468] time: 52.0545, train_loss: 0.22504240, train_accuracy: 0.9297, test_Accuracy: 0.9170
# Epoch: [ 0] [  341/  468] time: 52.1934, train_loss: 0.35290697, train_accuracy: 0.8984, test_Accuracy: 0.9181
# Epoch: [ 0] [  342/  468] time: 52.3262, train_loss: 0.36262208, train_accuracy: 0.8672, test_Accuracy: 0.9177
# Epoch: [ 0] [  343/  468] time: 52.4687, train_loss: 0.29580653, train_accuracy: 0.9609, test_Accuracy: 0.9172
# Epoch: [ 0] [  344/  468] time: 52.5978, train_loss: 0.26487729, train_accuracy: 0.9062, test_Accuracy: 0.9169
# Epoch: [ 0] [  345/  468] time: 52.7350, train_loss: 0.41209286, train_accuracy: 0.8672, test_Accuracy: 0.9167
# Epoch: [ 0] [  346/  468] time: 52.8666, train_loss: 0.44317955, train_accuracy: 0.8672, test_Accuracy: 0.9152
# Epoch: [ 0] [  347/  468] time: 53.0031, train_loss: 0.30544740, train_accuracy: 0.9219, test_Accuracy: 0.9147
# Epoch: [ 0] [  348/  468] time: 53.1329, train_loss: 0.36863214, train_accuracy: 0.9141, test_Accuracy: 0.9153
# Epoch: [ 0] [  349/  468] time: 53.2748, train_loss: 0.29368991, train_accuracy: 0.9219, test_Accuracy: 0.9149
# Epoch: [ 0] [  350/  468] time: 53.4191, train_loss: 0.22523952, train_accuracy: 0.9297, test_Accuracy: 0.9155
# Epoch: [ 0] [  351/  468] time: 53.5724, train_loss: 0.29145390, train_accuracy: 0.9219, test_Accuracy: 0.9164
# Epoch: [ 0] [  352/  468] time: 53.7107, train_loss: 0.32275945, train_accuracy: 0.8984, test_Accuracy: 0.9163
# Epoch: [ 0] [  353/  468] time: 53.8488, train_loss: 0.33459890, train_accuracy: 0.8984, test_Accuracy: 0.9166
# Epoch: [ 0] [  354/  468] time: 53.9749, train_loss: 0.25548869, train_accuracy: 0.9141, test_Accuracy: 0.9174
# Epoch: [ 0] [  355/  468] time: 54.1097, train_loss: 0.31676412, train_accuracy: 0.8906, test_Accuracy: 0.9181
# Epoch: [ 0] [  356/  468] time: 54.2473, train_loss: 0.24705443, train_accuracy: 0.9375, test_Accuracy: 0.9180
# Epoch: [ 0] [  357/  468] time: 54.4017, train_loss: 0.37873492, train_accuracy: 0.8906, test_Accuracy: 0.9177
# Epoch: [ 0] [  358/  468] time: 54.5335, train_loss: 0.21035245, train_accuracy: 0.9453, test_Accuracy: 0.9172
# Epoch: [ 0] [  359/  468] time: 54.6734, train_loss: 0.29344207, train_accuracy: 0.9141, test_Accuracy: 0.9167
# Epoch: [ 0] [  360/  468] time: 54.8147, train_loss: 0.26613504, train_accuracy: 0.9219, test_Accuracy: 0.9163
# Epoch: [ 0] [  361/  468] time: 54.9746, train_loss: 0.21329191, train_accuracy: 0.9375, test_Accuracy: 0.9164
# Epoch: [ 0] [  362/  468] time: 55.1037, train_loss: 0.20148535, train_accuracy: 0.9453, test_Accuracy: 0.9172
# Epoch: [ 0] [  363/  468] time: 55.2356, train_loss: 0.37329948, train_accuracy: 0.8672, test_Accuracy: 0.9178
# Epoch: [ 0] [  364/  468] time: 55.3742, train_loss: 0.30816171, train_accuracy: 0.8750, test_Accuracy: 0.9178
# Epoch: [ 0] [  365/  468] time: 55.5098, train_loss: 0.32755023, train_accuracy: 0.8906, test_Accuracy: 0.9181
# Epoch: [ 0] [  366/  468] time: 55.6592, train_loss: 0.24172728, train_accuracy: 0.9531, test_Accuracy: 0.9183
# Epoch: [ 0] [  367/  468] time: 55.8117, train_loss: 0.30735725, train_accuracy: 0.9062, test_Accuracy: 0.9180
# Epoch: [ 0] [  368/  468] time: 55.9720, train_loss: 0.15368292, train_accuracy: 0.9688, test_Accuracy: 0.9175
# Epoch: [ 0] [  369/  468] time: 56.1276, train_loss: 0.36430347, train_accuracy: 0.8359, test_Accuracy: 0.9163
# Epoch: [ 0] [  370/  468] time: 56.2725, train_loss: 0.29405805, train_accuracy: 0.9141, test_Accuracy: 0.9164
# Epoch: [ 0] [  371/  468] time: 56.4071, train_loss: 0.22310720, train_accuracy: 0.9375, test_Accuracy: 0.9157
# Epoch: [ 0] [  372/  468] time: 56.5411, train_loss: 0.25400293, train_accuracy: 0.9375, test_Accuracy: 0.9148
# Epoch: [ 0] [  373/  468] time: 56.6782, train_loss: 0.17813334, train_accuracy: 0.9375, test_Accuracy: 0.9139
# Epoch: [ 0] [  374/  468] time: 56.8214, train_loss: 0.40345263, train_accuracy: 0.8750, test_Accuracy: 0.9141
# Epoch: [ 0] [  375/  468] time: 56.9879, train_loss: 0.30616876, train_accuracy: 0.9219, test_Accuracy: 0.9143
# Epoch: [ 0] [  376/  468] time: 57.1315, train_loss: 0.21129686, train_accuracy: 0.9297, test_Accuracy: 0.9141
# Epoch: [ 0] [  377/  468] time: 57.2805, train_loss: 0.38866180, train_accuracy: 0.9141, test_Accuracy: 0.9145
# Epoch: [ 0] [  378/  468] time: 57.4460, train_loss: 0.38442135, train_accuracy: 0.9219, test_Accuracy: 0.9146
# Epoch: [ 0] [  379/  468] time: 57.5875, train_loss: 0.20781091, train_accuracy: 0.9688, test_Accuracy: 0.9163
# Epoch: [ 0] [  380/  468] time: 57.7279, train_loss: 0.16653278, train_accuracy: 0.9375, test_Accuracy: 0.9180
# Epoch: [ 0] [  381/  468] time: 57.8796, train_loss: 0.29837486, train_accuracy: 0.8984, test_Accuracy: 0.9191
# Epoch: [ 0] [  382/  468] time: 58.0279, train_loss: 0.25477013, train_accuracy: 0.9219, test_Accuracy: 0.9194
# Epoch: [ 0] [  383/  468] time: 58.1733, train_loss: 0.28139991, train_accuracy: 0.8984, test_Accuracy: 0.9185
# Epoch: [ 0] [  384/  468] time: 58.3131, train_loss: 0.25093210, train_accuracy: 0.9219, test_Accuracy: 0.9181
# Epoch: [ 0] [  385/  468] time: 58.4489, train_loss: 0.25684828, train_accuracy: 0.9297, test_Accuracy: 0.9175
# Epoch: [ 0] [  386/  468] time: 58.5925, train_loss: 0.38035300, train_accuracy: 0.8984, test_Accuracy: 0.9178
# Epoch: [ 0] [  387/  468] time: 58.7482, train_loss: 0.40029788, train_accuracy: 0.8828, test_Accuracy: 0.9174
# Epoch: [ 0] [  388/  468] time: 58.8887, train_loss: 0.25749716, train_accuracy: 0.9219, test_Accuracy: 0.9163
# Epoch: [ 0] [  389/  468] time: 59.0516, train_loss: 0.24167533, train_accuracy: 0.9219, test_Accuracy: 0.9161
# Epoch: [ 0] [  390/  468] time: 59.2010, train_loss: 0.33549172, train_accuracy: 0.9141, test_Accuracy: 0.9170
# Epoch: [ 0] [  391/  468] time: 59.4052, train_loss: 0.24296001, train_accuracy: 0.9453, test_Accuracy: 0.9179
# Epoch: [ 0] [  392/  468] time: 59.5685, train_loss: 0.28077942, train_accuracy: 0.9297, test_Accuracy: 0.9181
# Epoch: [ 0] [  393/  468] time: 59.7112, train_loss: 0.34321955, train_accuracy: 0.8906, test_Accuracy: 0.9185
# Epoch: [ 0] [  394/  468] time: 59.8517, train_loss: 0.18637037, train_accuracy: 0.9375, test_Accuracy: 0.9198
# Epoch: [ 0] [  395/  468] time: 60.0041, train_loss: 0.14119810, train_accuracy: 0.9531, test_Accuracy: 0.9196
# Epoch: [ 0] [  396/  468] time: 60.1562, train_loss: 0.27943569, train_accuracy: 0.9297, test_Accuracy: 0.9197
# Epoch: [ 0] [  397/  468] time: 60.2990, train_loss: 0.18579051, train_accuracy: 0.9453, test_Accuracy: 0.9188
# Epoch: [ 0] [  398/  468] time: 60.4410, train_loss: 0.30556017, train_accuracy: 0.9062, test_Accuracy: 0.9186
# Epoch: [ 0] [  399/  468] time: 60.5819, train_loss: 0.28329402, train_accuracy: 0.9219, test_Accuracy: 0.9188
# Epoch: [ 0] [  400/  468] time: 60.7535, train_loss: 0.18421796, train_accuracy: 0.9688, test_Accuracy: 0.9195
# Epoch: [ 0] [  401/  468] time: 60.9216, train_loss: 0.28764373, train_accuracy: 0.9062, test_Accuracy: 0.9193
# Epoch: [ 0] [  402/  468] time: 61.0671, train_loss: 0.21267024, train_accuracy: 0.9375, test_Accuracy: 0.9202
# Epoch: [ 0] [  403/  468] time: 61.2303, train_loss: 0.25667912, train_accuracy: 0.9219, test_Accuracy: 0.9207
# Epoch: [ 0] [  404/  468] time: 61.3799, train_loss: 0.29242086, train_accuracy: 0.9219, test_Accuracy: 0.9203
# Epoch: [ 0] [  405/  468] time: 61.5304, train_loss: 0.31163192, train_accuracy: 0.9141, test_Accuracy: 0.9202
# Epoch: [ 0] [  406/  468] time: 61.6764, train_loss: 0.17700803, train_accuracy: 0.9453, test_Accuracy: 0.9201
# Epoch: [ 0] [  407/  468] time: 61.8122, train_loss: 0.27384168, train_accuracy: 0.8984, test_Accuracy: 0.9211
# Epoch: [ 0] [  408/  468] time: 61.9563, train_loss: 0.22363715, train_accuracy: 0.9375, test_Accuracy: 0.9211
# Epoch: [ 0] [  409/  468] time: 62.1053, train_loss: 0.24740423, train_accuracy: 0.9141, test_Accuracy: 0.9205
# Epoch: [ 0] [  410/  468] time: 62.2434, train_loss: 0.29550561, train_accuracy: 0.8906, test_Accuracy: 0.9201
# Epoch: [ 0] [  411/  468] time: 62.3855, train_loss: 0.28791821, train_accuracy: 0.9219, test_Accuracy: 0.9206
# Epoch: [ 0] [  412/  468] time: 62.5265, train_loss: 0.27677155, train_accuracy: 0.9453, test_Accuracy: 0.9205
# Epoch: [ 0] [  413/  468] time: 62.6675, train_loss: 0.35895017, train_accuracy: 0.9062, test_Accuracy: 0.9211
# Epoch: [ 0] [  414/  468] time: 62.8175, train_loss: 0.28975341, train_accuracy: 0.9375, test_Accuracy: 0.9206
# Epoch: [ 0] [  415/  468] time: 62.9614, train_loss: 0.20325625, train_accuracy: 0.9531, test_Accuracy: 0.9204
# Epoch: [ 0] [  416/  468] time: 63.1119, train_loss: 0.31282899, train_accuracy: 0.9141, test_Accuracy: 0.9194
# Epoch: [ 0] [  417/  468] time: 63.2505, train_loss: 0.40855527, train_accuracy: 0.8750, test_Accuracy: 0.9197
# Epoch: [ 0] [  418/  468] time: 63.3871, train_loss: 0.29198954, train_accuracy: 0.9453, test_Accuracy: 0.9206
# Epoch: [ 0] [  419/  468] time: 63.5207, train_loss: 0.32125866, train_accuracy: 0.9062, test_Accuracy: 0.9221
# Epoch: [ 0] [  420/  468] time: 63.6511, train_loss: 0.27082849, train_accuracy: 0.8906, test_Accuracy: 0.9212
# Epoch: [ 0] [  421/  468] time: 63.7901, train_loss: 0.26236802, train_accuracy: 0.9375, test_Accuracy: 0.9211
# Epoch: [ 0] [  422/  468] time: 63.9199, train_loss: 0.34255496, train_accuracy: 0.9062, test_Accuracy: 0.9219
# Epoch: [ 0] [  423/  468] time: 64.0542, train_loss: 0.21691246, train_accuracy: 0.9453, test_Accuracy: 0.9217
# Epoch: [ 0] [  424/  468] time: 64.1829, train_loss: 0.27040142, train_accuracy: 0.9219, test_Accuracy: 0.9216
# Epoch: [ 0] [  425/  468] time: 64.3192, train_loss: 0.17589387, train_accuracy: 0.9531, test_Accuracy: 0.9208
# Epoch: [ 0] [  426/  468] time: 64.4475, train_loss: 0.31748626, train_accuracy: 0.9141, test_Accuracy: 0.9209
# Epoch: [ 0] [  427/  468] time: 64.5815, train_loss: 0.26899043, train_accuracy: 0.9453, test_Accuracy: 0.9209
# Epoch: [ 0] [  428/  468] time: 64.7099, train_loss: 0.27674592, train_accuracy: 0.9297, test_Accuracy: 0.9224
# Epoch: [ 0] [  429/  468] time: 64.8580, train_loss: 0.34694251, train_accuracy: 0.8906, test_Accuracy: 0.9217
# Epoch: [ 0] [  430/  468] time: 64.9912, train_loss: 0.27131698, train_accuracy: 0.9062, test_Accuracy: 0.9214
# Epoch: [ 0] [  431/  468] time: 65.1309, train_loss: 0.33014625, train_accuracy: 0.9219, test_Accuracy: 0.9206
# Epoch: [ 0] [  432/  468] time: 65.2631, train_loss: 0.25507164, train_accuracy: 0.9297, test_Accuracy: 0.9204
# Epoch: [ 0] [  433/  468] time: 65.3972, train_loss: 0.28177398, train_accuracy: 0.9297, test_Accuracy: 0.9185
# Epoch: [ 0] [  434/  468] time: 65.5289, train_loss: 0.25344208, train_accuracy: 0.9141, test_Accuracy: 0.9169
# Epoch: [ 0] [  435/  468] time: 65.6652, train_loss: 0.30959725, train_accuracy: 0.9375, test_Accuracy: 0.9163
# Epoch: [ 0] [  436/  468] time: 65.8035, train_loss: 0.18788157, train_accuracy: 0.9453, test_Accuracy: 0.9169
# Epoch: [ 0] [  437/  468] time: 65.9373, train_loss: 0.22948582, train_accuracy: 0.9297, test_Accuracy: 0.9182
# Epoch: [ 0] [  438/  468] time: 66.0693, train_loss: 0.30854362, train_accuracy: 0.8750, test_Accuracy: 0.9202
# Epoch: [ 0] [  439/  468] time: 66.2040, train_loss: 0.33726031, train_accuracy: 0.9062, test_Accuracy: 0.9212
# Epoch: [ 0] [  440/  468] time: 66.3322, train_loss: 0.24816132, train_accuracy: 0.9375, test_Accuracy: 0.9220
# Epoch: [ 0] [  441/  468] time: 66.4652, train_loss: 0.16330397, train_accuracy: 0.9609, test_Accuracy: 0.9227
# Epoch: [ 0] [  442/  468] time: 66.6405, train_loss: 0.35074097, train_accuracy: 0.9062, test_Accuracy: 0.9226
# Epoch: [ 0] [  443/  468] time: 66.8358, train_loss: 0.25663245, train_accuracy: 0.9297, test_Accuracy: 0.9222
# Epoch: [ 0] [  444/  468] time: 67.0001, train_loss: 0.38637742, train_accuracy: 0.8672, test_Accuracy: 0.9220
# Epoch: [ 0] [  445/  468] time: 67.1504, train_loss: 0.28388107, train_accuracy: 0.9297, test_Accuracy: 0.9221
# Epoch: [ 0] [  446/  468] time: 67.2917, train_loss: 0.27633795, train_accuracy: 0.8984, test_Accuracy: 0.9231
# Epoch: [ 0] [  447/  468] time: 67.4346, train_loss: 0.29737395, train_accuracy: 0.8984, test_Accuracy: 0.9232
# Epoch: [ 0] [  448/  468] time: 67.5876, train_loss: 0.30795231, train_accuracy: 0.9062, test_Accuracy: 0.9234
# Epoch: [ 0] [  449/  468] time: 67.7393, train_loss: 0.26688886, train_accuracy: 0.9062, test_Accuracy: 0.9222
# Epoch: [ 0] [  450/  468] time: 67.8876, train_loss: 0.28602099, train_accuracy: 0.9062, test_Accuracy: 0.9230
# Epoch: [ 0] [  451/  468] time: 68.0310, train_loss: 0.21263117, train_accuracy: 0.9453, test_Accuracy: 0.9237
# Epoch: [ 0] [  452/  468] time: 68.1674, train_loss: 0.30298805, train_accuracy: 0.9219, test_Accuracy: 0.9237
# Epoch: [ 0] [  453/  468] time: 68.3032, train_loss: 0.20599817, train_accuracy: 0.9375, test_Accuracy: 0.9240
# Epoch: [ 0] [  454/  468] time: 68.4335, train_loss: 0.33815253, train_accuracy: 0.8750, test_Accuracy: 0.9236
# Epoch: [ 0] [  455/  468] time: 68.5668, train_loss: 0.25075701, train_accuracy: 0.9141, test_Accuracy: 0.9235
# Epoch: [ 0] [  456/  468] time: 68.6947, train_loss: 0.27105916, train_accuracy: 0.9219, test_Accuracy: 0.9237
# Epoch: [ 0] [  457/  468] time: 68.8279, train_loss: 0.20743844, train_accuracy: 0.9453, test_Accuracy: 0.9236
# Epoch: [ 0] [  458/  468] time: 68.9554, train_loss: 0.27967137, train_accuracy: 0.8906, test_Accuracy: 0.9238
# Epoch: [ 0] [  459/  468] time: 69.0887, train_loss: 0.30981982, train_accuracy: 0.9141, test_Accuracy: 0.9233
# Epoch: [ 0] [  460/  468] time: 69.2174, train_loss: 0.21934325, train_accuracy: 0.9297, test_Accuracy: 0.9231
# Epoch: [ 0] [  461/  468] time: 69.3550, train_loss: 0.27825075, train_accuracy: 0.9219, test_Accuracy: 0.9231
# Epoch: [ 0] [  462/  468] time: 69.4842, train_loss: 0.20014793, train_accuracy: 0.9297, test_Accuracy: 0.9233
# Epoch: [ 0] [  463/  468] time: 69.6174, train_loss: 0.26499462, train_accuracy: 0.9453, test_Accuracy: 0.9232
# Epoch: [ 0] [  464/  468] time: 69.7506, train_loss: 0.21966346, train_accuracy: 0.9297, test_Accuracy: 0.9229
# Epoch: [ 0] [  465/  468] time: 69.8840, train_loss: 0.19204132, train_accuracy: 0.9531, test_Accuracy: 0.9241
# Epoch: [ 0] [  466/  468] time: 70.0225, train_loss: 0.27420744, train_accuracy: 0.9375, test_Accuracy: 0.9239
# Epoch: [ 0] [  467/  468] time: 70.1820, train_loss: 0.21703413, train_accuracy: 0.9297, test_Accuracy: 0.9245

# %% [markdown]
# ## Test Accuracy : 0.9245
